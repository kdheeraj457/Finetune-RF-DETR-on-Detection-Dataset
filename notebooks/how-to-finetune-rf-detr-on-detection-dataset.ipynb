# %% [markdown]
# <a href="https://colab.research.google.com/github/kdheeraj457/Finetune-RF-DETR-on-Detection-Dataset/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
# [![hf space](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/SkalskiP/RF-DETR)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb)
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time transformer architecture for object detection and instance segmentation developed by Roboflow. Built on a DINOv2 vision transformer backbone, RF-DETR delivers state-of-the-art accuracy and latency trade-offs on [Microsoft COCO](https://cocodataset.org/#home) and [RF100-VL](https://github.com/roboflow/rf100-vl).
#
# RF-DETR uses a DINOv2 vision transformer backbone and supports both detection and instance segmentation in a single, consistent API. All core models and code are released under the Apache 2.0 license.
#
# <img alt="rf_detr_1-4_latency_accuracy_object_detection" src="https://storage.googleapis.com/com-roboflow-marketing/rf-detr/rf_detr_1-4_latency_accuracy_object_detection.png" />

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API Key
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy` to copy your private API key.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store your Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Fri Jun 19 21:42:27 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0             27W /   70W |     377MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           41472      C   /usr/bin/python3                        374MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies
#
# Installs RF-DETR version 1.4.0 or higher, along with Supervision for benchmarking and Roboflow for pulling datasets and uploading models to the Roboflow platform.

# %%
# !pip install -q rfdetr>=1.4.0 supervision roboflow

# %% [markdown]
# ### Download example data
#
# Downloads example images for testing. You can use these or replace them with your own images.

# %%
# !wget -q https://media.roboflow.com/notebooks/examples/dog-2.jpeg
# !wget -q https://media.roboflow.com/notebooks/examples/dog-3.jpeg

# %% [markdown]
# ## Inference with Pre-trained COCO Model
#
# Runs inference on an example image using a pretrained RF-DETR Medium model (trained on COCO). To use a different model size, simply replace `RFDETRMedium` with `RFDETRNano`, `RFDETRSmall`, `RFDETRBase` or `RFDETRLarge` as needed.

# %%
import numpy as np
import supervision as sv

from PIL import Image

from rfdetr import RFDETRMedium
from rfdetr.util.coco_classes import COCO_CLASSES

image = Image.open("dog-2.jpeg")

model = RFDETRMedium(resolution=640)
model.optimize_for_inference()

detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image.thumbnail((800, 800))
annotated_image
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# <PIL.Image.Image image mode=RGB size=450x800>

# %% [markdown]
# ## Download Dataset from Roboflow Universe
#
# RF-DETR expects the dataset to be in COCO format. Divide your dataset into three subdirectories: `train`, `valid`, and `test`. Each subdirectory should contain its own `_annotations.coco.json` file that holds the annotations for that particular split, along with the corresponding image files. Below is an example of the directory structure:
#
# ```
# dataset/
# ├── train/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# ├── valid/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# └── test/
#     ├── _annotations.coco.json
#     ├── image1.jpg
#     ├── image2.jpg
#     └── ... (other image files)
# ```
#
# [Roboflow](https://roboflow.com/annotate) allows you to create object detection datasets from scratch or convert existing datasets from formats like YOLO, and then export them in COCO JSON format for training. You can also explore [Roboflow Universe](https://universe.roboflow.com/) to find pre-labeled datasets for a range of use cases.

# %%
# !pip install "rfdetr[train,loggers]"
# Out:
# Requirement already satisfied: rfdetr[loggers,train] in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.34.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.0.2)
# Requirement already satisfied: torch>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (0.26.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (4.67.3)
# Requirement already satisfied: transformers<6.0.0,>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (5.9.0)
# Requirement already satisfied: pydantic<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.11.10)
# Requirement already satisfied: supervision>=0.29.0 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (0.29.0.post0)
# Requirement already satisfied: pyDeprecate<0.10,>=0.9 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (0.9.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (0.19.1)
# Requirement already satisfied: pytorch_lightning!=2.6.2,!=2.6.3,<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.6.5)
# Requirement already satisfied: torchmetrics>=1.2 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[detection]>=1.2; extra == "train"->rfdetr[loggers,train]) (1.9.0)
# Requirement already satisfied: faster-coco-eval>=1.7.2 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (1.7.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.0.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (1.16.3)
# Requirement already satisfied: albumentations<3.0.0,>=1.4.24 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.0.8)
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (1.3.10)
# Requirement already satisfied: rf100vl in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (1.1.2)
# Requirement already satisfied: tensorboard>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.20.0)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (5.29.6)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (0.27.2)
# Requirement already satisfied: mlflow in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (3.14.0)
# Requirement already satisfied: clearml in /usr/local/lib/python3.12/dist-packages (from rfdetr[loggers,train]) (2.1.9)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations<3.0.0,>=1.4.24->rfdetr[loggers,train]) (6.0.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations<3.0.0,>=1.4.24->rfdetr[loggers,train]) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations<3.0.0,>=1.4.24->rfdetr[loggers,train]) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations<3.0.0,>=1.4.24->rfdetr[loggers,train]) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations<3.0.0,>=1.4.24->rfdetr[loggers,train]) (6.5.16)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0->rfdetr[loggers,train]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0->rfdetr[loggers,train]) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0->rfdetr[loggers,train]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0->rfdetr[loggers,train]) (0.4.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning!=2.6.2,!=2.6.3,<3,>=2.6->rfdetr[loggers,train]) (2025.3.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning!=2.6.2,!=2.6.3,<3,>=2.6->rfdetr[loggers,train]) (24.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning!=2.6.2,!=2.6.3,<3,>=2.6->rfdetr[loggers,train]) (0.15.3)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from supervision>=0.29.0->rfdetr[loggers,train]) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from supervision>=0.29.0->rfdetr[loggers,train]) (3.10.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.12/dist-packages (from supervision>=0.29.0->rfdetr[loggers,train]) (4.10.0.84)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.12/dist-packages (from supervision>=0.29.0->rfdetr[loggers,train]) (12.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->rfdetr[loggers,train]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->rfdetr[loggers,train]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests->rfdetr[loggers,train]) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests->rfdetr[loggers,train]) (2026.5.20)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.13.0->rfdetr[loggers,train]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.13.0->rfdetr[loggers,train]) (1.81.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.13.0->rfdetr[loggers,train]) (3.10.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.13.0->rfdetr[loggers,train]) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.13.0->rfdetr[loggers,train]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.13.0->rfdetr[loggers,train]) (3.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (3.29.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->rfdetr[loggers,train]) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->rfdetr[loggers,train]) (12.8.90)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (1.13.0)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (0.16.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (0.8.0)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (26.1.0)
# Requirement already satisfied: furl>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (2.1.4)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (4.26.0)
# Requirement already satisfied: pathlib2>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (2.3.7.post1)
# Requirement already satisfied: psutil>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (7.2.2)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (2.9.0.post0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (2.13.0)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (1.17.0)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.12/dist-packages (from clearml->rfdetr[loggers,train]) (0.37.0)
# Requirement already satisfied: mlflow-skinny==3.14.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (3.14.0)
# Requirement already satisfied: mlflow-tracing==3.14.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (3.14.0)
# Requirement already satisfied: Flask-CORS<7 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (6.0.5)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (3.1.3)
# Requirement already satisfied: aiohttp<4,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (3.14.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (1.18.4)
# Requirement already satisfied: cryptography<49,>=43.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (48.0.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (7.1.0)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (3.4.3)
# Requirement already satisfied: gunicorn<27 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (26.0.0)
# Requirement already satisfied: huey<4,>=2.5.4 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (3.0.3)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (2.3.3)
# Requirement already satisfied: pyarrow<25,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (1.6.1)
# Requirement already satisfied: skops<1 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (0.14.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow->rfdetr[loggers,train]) (2.0.50)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (8.4.1)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (0.118.0)
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (0.115.14)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (3.1.50)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (1.38.0)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (1.0.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (0.5.5)
# Requirement already satisfied: starlette<2 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (0.46.2)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (0.49.0)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft->rfdetr[loggers,train]) (1.13.0)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow->rfdetr[loggers,train]) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow->rfdetr[loggers,train]) (1.5.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow->rfdetr[loggers,train]) (1.4.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow->rfdetr[loggers,train]) (1.5.5)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow->rfdetr[loggers,train]) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow->rfdetr[loggers,train]) (1.2.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->rfdetr[loggers,train]) (4.10.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->rfdetr[loggers,train]) (2.62.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow->rfdetr[loggers,train]) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow->rfdetr[loggers,train]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow->rfdetr[loggers,train]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow->rfdetr[loggers,train]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow->rfdetr[loggers,train]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.0->mlflow->rfdetr[loggers,train]) (1.24.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic!=1.10.0,<2->mlflow->rfdetr[loggers,train]) (1.3.12)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography<49,>=43.0.0->mlflow->rfdetr[loggers,train]) (2.0.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.2.0->rfdetr[loggers,train]) (1.5.5)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow->rfdetr[loggers,train]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow->rfdetr[loggers,train]) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow->rfdetr[loggers,train]) (3.0.3)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from furl>=2.0.0->clearml->rfdetr[loggers,train]) (1.0.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (4.0.12)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow->rfdetr[loggers,train]) (3.2.11)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow->rfdetr[loggers,train]) (3.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (0.28.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->clearml->rfdetr[loggers,train]) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6.0->clearml->rfdetr[loggers,train]) (2026.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->supervision>=0.29.0->rfdetr[loggers,train]) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->supervision>=0.29.0->rfdetr[loggers,train]) (4.63.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3->mlflow->rfdetr[loggers,train]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3->mlflow->rfdetr[loggers,train]) (2026.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow->rfdetr[loggers,train]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow->rfdetr[loggers,train]) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in /usr/local/lib/python3.12/dist-packages (from skops<1->mlflow->rfdetr[loggers,train]) (3.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow->rfdetr[loggers,train]) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2.0->rfdetr[loggers,train]) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (14.3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography<49,>=43.0.0->mlflow->rfdetr[loggers,train]) (3.0)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (2.47.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (5.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (4.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (0.59b0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.9->skops<1->mlflow->rfdetr[loggers,train]) (0.8.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (2.20.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (4.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers<6.0.0,>=5.1.0->rfdetr[loggers,train]) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow->rfdetr[loggers,train]) (0.6.3)

# %%
from roboflow import download_dataset

dataset = download_dataset("https://app.roboflow.com/dheerajs-workspace-j2hot/helmet-person-vest-q6ntj/1", "coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.

# %%
from rfdetr import RFDETRNano

model = RFDETRNano()

model.train(dataset_dir=dataset.location, epochs=4, batch_size=4, grad_accum_steps=2)
# Out:
# [2026-06-19 21:44:47] [INFO] rf-detr - File /root/.roboflow/models/rf-detr-nano.pth already exists with correct MD5 hash.
# [2026-06-19 21:44:47] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-06-19 21:44:47] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-06-19 21:44:48] [INFO] rf-detr - File /root/.roboflow/models/rf-detr-nano.pth already exists with correct MD5 hash.
# [2026-06-19 21:44:49] [WARNING] rf-detr - Pretrained weights at '/root/.roboflow/models/rf-detr-nano.pth' loaded only partially — this typically produces lower accuracy. 1 model parameter(s) not in checkpoint (left at random init): [_kp_active_mask]. Check that the model configuration (encoder, hidden_dim, out_feature_indexes, projector_scale, ...) matches the architecture the checkpoint was trained with.
# [2026-06-19 21:44:49] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-06-19 21:44:49] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-06-19 21:44:50] [INFO] rf-detr - File /root/.roboflow/models/rf-detr-nano.pth already exists with correct MD5 hash.
# [2026-06-19 21:44:51] [WARNING] rf-detr - Checkpoint has 90 classes but model is configured for 8. The detection head will be re-initialized to 8 classes.
# [2026-06-19 21:44:52] [WARNING] rf-detr - Pretrained weights at '/root/.roboflow/models/rf-detr-nano.pth' loaded only partially — this typically produces lower accuracy. 1 model parameter(s) not in checkpoint (left at random init): [_kp_active_mask]. Check that the model configuration (encoder, hidden_dim, out_feature_indexes, projector_scale, ...) matches the architecture the checkpoint was trained with.
# INFO:pytorch_lightning.utilities.rank_zero:Using bfloat16 Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# [2026-06-19 21:44:52] [INFO] rf-detr - Building Roboflow train dataset with square resize at resolution 384
# [2026-06-19 21:44:52] [INFO] rf-detr - Using multi-scale training with square resize and scales: [544]
# [2026-06-19 21:44:52] [INFO] rf-detr - Built 1 Albumentations transforms from config
# [2026-06-19 21:44:52] [INFO] rf-detr - Built 1 Albumentations transforms from config
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# [2026-06-19 21:44:52] [INFO] rf-detr - Building Roboflow val dataset with square resize at resolution 384
# [2026-06-19 21:44:52] [INFO] rf-detr - Using multi-scale training with square resize and scales: [544]
# [2026-06-19 21:44:52] [INFO] rf-detr - Built 1 Albumentations transforms from config
# Experiment logs directory output/ exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Checkpoint directory /content/output exists and is not empty.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loading `train_dataloader` to estimate number of stepping batches.
# `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name        ┃ Type         ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model       │ LWDETR       │ 30.2 M │ train │     0 │
# │ 1 │ criterion   │ SetCriterion │      0 │ train │     0 │
# │ 2 │ postprocess │ PostProcess  │      0 │ train │     0 │
# └───┴─────────────┴──────────────┴────────┴───────┴───────┘
# Trainable params: 30.2 M
# Non-trainable params: 0
# Total params: 30.2 M
# Total estimated model params size (MB): 120.689
# Modules in train mode: 449
# Modules in eval mode: 0
# Total FLOPs: 0
# Output()
# [2026-06-19 21:44:55] [INFO] rf-detr - Best EMA mAP improved to 0.0943 (epoch 0)
# [2026-06-19 21:52:09] [INFO] rf-detr - Best regular checkpoint saved to /content/output/checkpoint_best_regular.pth (epoch 0, monitor=val/mAP_50_95, value=0.349948)
# [2026-06-19 21:52:14] [INFO] rf-detr - Best EMA mAP improved to 0.3610 (epoch 0)
# [2026-06-19 21:59:40] [INFO] rf-detr - Best regular checkpoint saved to /content/output/checkpoint_best_regular.pth (epoch 1, monitor=val/mAP_50_95, value=0.378592)
# [2026-06-19 21:59:46] [INFO] rf-detr - Best EMA mAP improved to 0.3897 (epoch 1)
# [2026-06-19 22:07:23] [INFO] rf-detr - Best regular checkpoint saved to /content/output/checkpoint_best_regular.pth (epoch 2, monitor=val/mAP_50_95, value=0.381828)
# [2026-06-19 22:07:23] [INFO] rf-detr - Best EMA mAP improved to 0.4003 (epoch 2)
# [2026-06-19 22:15:02] [INFO] rf-detr - Best regular checkpoint saved to /content/output/checkpoint_best_regular.pth (epoch 3, monitor=val/mAP_50_95, value=0.384125)
# [2026-06-19 22:15:02] [INFO] rf-detr - Best EMA mAP improved to 0.4008 (epoch 3)
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=4` reached.
# [2026-06-19 22:15:48] [INFO] rf-detr - Best total checkpoint saved from EMA (regular=0.3841, ema=0.4008)

# %%
import pandas as pd

df = pd.read_csv("/content/output/metrics.csv")

df
# Out:
#     epoch  step  train/cardinality_error  train/cardinality_error_0  \
# 0       0    49                      NaN                        NaN
# 1       0    99                      NaN                        NaN
# 2       0   149                      NaN                        NaN
# 3       0   199                      NaN                        NaN
# 4       0   249                      NaN                        NaN
# 5       0   299                      NaN                        NaN
# 6       0   300                      NaN                        NaN
# 7       0   300              3880.619629                3878.996338
# 8       1   349                      NaN                        NaN
# 9       1   399                      NaN                        NaN
# 10      1   449                      NaN                        NaN
# 11      1   499                      NaN                        NaN
# 12      1   549                      NaN                        NaN
# 13      1   599                      NaN                        NaN
# 14      1   601                      NaN                        NaN
# 15      1   601              3887.956299                3891.101807
# 16      2   649                      NaN                        NaN
# 17      2   699                      NaN                        NaN
# 18      2   749                      NaN                        NaN
# 19      2   799                      NaN                        NaN
# 20      2   849                      NaN                        NaN
# 21      2   899                      NaN                        NaN
# 22      2   902                      NaN                        NaN
# 23      2   902              3889.678955                3891.875488
# 24      3   949                      NaN                        NaN
# 25      3   999                      NaN                        NaN
# 26      3  1049                      NaN                        NaN
# 27      3  1099                      NaN                        NaN
# 28      3  1149                      NaN                        NaN
# 29      3  1199                      NaN                        NaN
# 30      3  1203                      NaN                        NaN
# 31      3  1203              3891.318604                3892.360352
#
#     train/cardinality_error_enc  train/class_error  train/loss  \
# 0                           NaN                NaN         NaN
# 1                           NaN                NaN         NaN
# 2                           NaN                NaN         NaN
# 3                           NaN                NaN         NaN
# 4                           NaN                NaN         NaN
# 5                           NaN                NaN         NaN
# 6                           NaN                NaN         NaN
# 7                   3674.774902          32.796318    4.824245
# 8                           NaN                NaN         NaN
# 9                           NaN                NaN         NaN
# 10                          NaN                NaN         NaN
# 11                          NaN                NaN         NaN
# 12                          NaN                NaN         NaN
# 13                          NaN                NaN         NaN
# 14                          NaN                NaN         NaN
# 15                  3683.492432          19.041075    4.331816
# 16                          NaN                NaN         NaN
# 17                          NaN                NaN         NaN
# 18                          NaN                NaN         NaN
# 19                          NaN                NaN         NaN
# 20                          NaN                NaN         NaN
# 21                          NaN                NaN         NaN
# 22                          NaN                NaN         NaN
# 23                  3712.961426          15.984516    4.164490
# 24                          NaN                NaN         NaN
# 25                          NaN                NaN         NaN
# 26                          NaN                NaN         NaN
# 27                          NaN                NaN         NaN
# 28                          NaN                NaN         NaN
# 29                          NaN                NaN         NaN
# 30                          NaN                NaN         NaN
# 31                  3702.806152          14.800103    4.085408
#
#     train/loss_bbox  train/loss_bbox_0  train/loss_bbox_enc  ...  \
# 0               NaN                NaN                  NaN  ...
# 1               NaN                NaN                  NaN  ...
# 2               NaN                NaN                  NaN  ...
# 3               NaN                NaN                  NaN  ...
# 4               NaN                NaN                  NaN  ...
# 5               NaN                NaN                  NaN  ...
# 6               NaN                NaN                  NaN  ...
# 7          0.049000           0.050000             0.061582  ...
# 8               NaN                NaN                  NaN  ...
# 9               NaN                NaN                  NaN  ...
# 10              NaN                NaN                  NaN  ...
# 11              NaN                NaN                  NaN  ...
# 12              NaN                NaN                  NaN  ...
# 13              NaN                NaN                  NaN  ...
# 14              NaN                NaN                  NaN  ...
# 15         0.047004           0.048534             0.058708  ...
# 16              NaN                NaN                  NaN  ...
# 17              NaN                NaN                  NaN  ...
# 18              NaN                NaN                  NaN  ...
# 19              NaN                NaN                  NaN  ...
# 20              NaN                NaN                  NaN  ...
# 21              NaN                NaN                  NaN  ...
# 22              NaN                NaN                  NaN  ...
# 23         0.045611           0.046720             0.057350  ...
# 24              NaN                NaN                  NaN  ...
# 25              NaN                NaN                  NaN  ...
# 26              NaN                NaN                  NaN  ...
# 27              NaN                NaN                  NaN  ...
# 28              NaN                NaN                  NaN  ...
# 29              NaN                NaN                  NaN  ...
# 30              NaN                NaN                  NaN  ...
# 31         0.045153           0.046498             0.057470  ...
#
#     val/loss_ce_enc  val/loss_giou  val/loss_giou_0  val/loss_giou_enc  \
# 0               NaN            NaN              NaN                NaN
# 1               NaN            NaN              NaN                NaN
# 2               NaN            NaN              NaN                NaN
# 3               NaN            NaN              NaN                NaN
# 4               NaN            NaN              NaN                NaN
# 5               NaN            NaN              NaN                NaN
# 6          0.816846       0.208442         0.210347           0.234335
# 7               NaN            NaN              NaN                NaN
# 8               NaN            NaN              NaN                NaN
# 9               NaN            NaN              NaN                NaN
# 10              NaN            NaN              NaN                NaN
# 11              NaN            NaN              NaN                NaN
# 12              NaN            NaN              NaN                NaN
# 13              NaN            NaN              NaN                NaN
# 14         0.774755       0.208741         0.209803           0.230633
# 15              NaN            NaN              NaN                NaN
# 16              NaN            NaN              NaN                NaN
# 17              NaN            NaN              NaN                NaN
# 18              NaN            NaN              NaN                NaN
# 19              NaN            NaN              NaN                NaN
# 20              NaN            NaN              NaN                NaN
# 21              NaN            NaN              NaN                NaN
# 22         0.760002       0.209591         0.210113           0.233565
# 23              NaN            NaN              NaN                NaN
# 24              NaN            NaN              NaN                NaN
# 25              NaN            NaN              NaN                NaN
# 26              NaN            NaN              NaN                NaN
# 27              NaN            NaN              NaN                NaN
# 28              NaN            NaN              NaN                NaN
# 29              NaN            NaN              NaN                NaN
# 30         0.755906       0.209483         0.210500           0.231732
# 31              NaN            NaN              NaN                NaN
#
#     val/mAP_50  val/mAP_50_95  val/mAP_75   val/mAR  val/precision  val/recall
# 0          NaN            NaN         NaN       NaN            NaN         NaN
# 1          NaN            NaN         NaN       NaN            NaN         NaN
# 2          NaN            NaN         NaN       NaN            NaN         NaN
# 3          NaN            NaN         NaN       NaN            NaN         NaN
# 4          NaN            NaN         NaN       NaN            NaN         NaN
# 5          NaN            NaN         NaN       NaN            NaN         NaN
# 6     0.573136       0.349948    0.365067  0.635486       0.549353    0.649490
# 7          NaN            NaN         NaN       NaN            NaN         NaN
# 8          NaN            NaN         NaN       NaN            NaN         NaN
# 9          NaN            NaN         NaN       NaN            NaN         NaN
# 10         NaN            NaN         NaN       NaN            NaN         NaN
# 11         NaN            NaN         NaN       NaN            NaN         NaN
# 12         NaN            NaN         NaN       NaN            NaN         NaN
# 13         NaN            NaN         NaN       NaN            NaN         NaN
# 14    0.626697       0.378592    0.389167  0.634938       0.594632    0.651178
# 15         NaN            NaN         NaN       NaN            NaN         NaN
# 16         NaN            NaN         NaN       NaN            NaN         NaN
# 17         NaN            NaN         NaN       NaN            NaN         NaN
# 18         NaN            NaN         NaN       NaN            NaN         NaN
# 19         NaN            NaN         NaN       NaN            NaN         NaN
# 20         NaN            NaN         NaN       NaN            NaN         NaN
# 21         NaN            NaN         NaN       NaN            NaN         NaN
# 22    0.628093       0.381828    0.402619  0.638829       0.639353    0.620531
# 23         NaN            NaN         NaN       NaN            NaN         NaN
# 24         NaN            NaN         NaN       NaN            NaN         NaN
# 25         NaN            NaN         NaN       NaN            NaN         NaN
# 26         NaN            NaN         NaN       NaN            NaN         NaN
# 27         NaN            NaN         NaN       NaN            NaN         NaN
# 28         NaN            NaN         NaN       NaN            NaN         NaN
# 29         NaN            NaN         NaN       NaN            NaN         NaN
# 30    0.633446       0.384125    0.401837  0.646694       0.681569    0.595092
# 31         NaN            NaN         NaN       NaN            NaN         NaN
#
# [32 rows x 50 columns]

# %%
# !ls -la /content/output
# Out:
# total 826588
# drwxr-xr-x 2 root root      4096 Jun 19 22:15 .
# drwxr-xr-x 1 root root      4096 Jun 19 21:42 ..
# -rw-r--r-- 1 root root 120893691 Jun 19 22:15 checkpoint_best_ema.pth
# -rw-r--r-- 1 root root 120927131 Jun 19 22:14 checkpoint_best_regular.pth
# -rw------- 1 root root 120882171 Jun 19 22:15 checkpoint_best_total.pth
# -rw-r--r-- 1 root root     12013 Jun 19 19:24 events.out.tfevents.1781895220.b962959060e7.6000.0
# -rw-r--r-- 1 root root        88 Jun 19 20:15 events.out.tfevents.1781900112.b962959060e7.27205.0
# -rw-r--r-- 1 root root        88 Jun 19 20:15 events.out.tfevents.1781900158.b962959060e7.27205.1
# -rw-r--r-- 1 root root      8211 Jun 19 20:28 events.out.tfevents.1781900173.b962959060e7.27205.2
# -rw-r--r-- 1 root root      3940 Jun 19 21:28 events.out.tfevents.1781903337.b962959060e7.41472.0
# -rw-r--r-- 1 root root       277 Jun 19 21:32 events.out.tfevents.1781904709.b962959060e7.41472.1
# -rw-r--r-- 1 root root     14972 Jun 19 22:15 events.out.tfevents.1781905492.b962959060e7.41472.2
# -rw-r--r-- 1 root root         3 Jun 19 18:53 hparams.yaml
# -rw------- 1 root root 483621183 Jun 19 22:15 last.ckpt
# -rw-r--r-- 1 root root      7347 Jun 19 22:15 metrics.csv
# -rw-r--r-- 1 root root      3851 Jun 19 22:15 training_config.json

# %% [markdown]
# ## Deploy a Trained RF-DETR Model
#
# Deploying to Roboflow allows you to create multi-step computer vision applications that run both in the cloud and your own hardware. Please wait a moment while Roboflow indexes your model.

# %%
model.deploy_to_roboflow(
  workspace="dheerajs-workspace-j2hot",
  project_id="helmet-person-vest-q6ntj",
  version=1,
  api_key=os.environ["ROBOFLOW_API_KEY"]
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.

# %% [markdown]
# ## Evaluate Fine-tuned RF-DETR Model

# %% [markdown]
# Before benchmarking the model, we need to load the best saved checkpoint. To ensure it fits on the GPU, we first need to free up GPU memory. This involves deleting any remaining references to previously used objects, triggering Python’s garbage collector, and clearing the CUDA memory cache.

# %%
import gc
import torch
import weakref

def cleanup_gpu_memory(obj=None, verbose: bool = False):

    if not torch.cuda.is_available():
        if verbose:
            print("[INFO] CUDA is not available. No GPU cleanup needed.")
        return

    def get_memory_stats():
        allocated = torch.cuda.memory_allocated()
        reserved = torch.cuda.memory_reserved()
        return allocated, reserved

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[Before] Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

    # Ensure we drop all strong references
    if obj is not None:
        ref = weakref.ref(obj)
        del obj
        if ref() is not None and verbose:
            print("[WARNING] Object not fully garbage collected yet.")

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[After]  Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

# %%
cleanup_gpu_memory(model, verbose=True)
# Out:
# [Before] Allocated: 116.91 MB | Reserved: 208.00 MB
# [WARNING] Object not fully garbage collected yet.
# [After]  Allocated: 0.00 MB | Reserved: 0.00 MB

# %% [markdown]
# We load the best-performing model from the `checkpoint_best_total.pth` file using the `RFDETRMedium` class. This checkpoint contains the trained weights from our most successful training run. After loading, we call `optimize_for_inference()`, which prepares the model for efficient inference.

# %%
model = RFDETRNano(pretrain_weights="/content/output/checkpoint_best_total.pth")
model.optimize_for_inference()
# Out:
# [2026-06-19 22:28:45] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-06-19 22:28:45] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-06-19 22:28:46] [WARNING] rf-detr - Checkpoint has 8 classes but model is configured for 90. Using checkpoint class count (8). Pass num_classes=8 to suppress this warning.
# [2026-06-19 22:28:46] [WARNING] rf-detr - load_pretrain_weights: args.num_queries absent; inferred ckpt_num_queries=300 from tensor rows 3900 ÷ ckpt_group_detr=13.
# [transformers] `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 131/131 [00:06<00:00, 20.08it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()
print(map_result)
# Out:
# Average Precision (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.484
# Average Precision (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.826
# Average Precision (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.475
# Average Precision (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.170
# Average Precision (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.498
# Average Precision (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735

# %% [markdown]
# ## Run Inference with Fine-tuned RF-DETR Model

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[45]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
from rfdetr import RFDETRNano

print(RFDETRNano.train.__doc__)
# Out:
# Train an RF-DETR model via the PyTorch Lightning stack.
#
#         All keyword arguments are forwarded to :meth:`get_train_config` to build a :class:`~rfdetr.config.TrainConfig`.
#         Several kwargs are absorbed and handled specially so that existing call-sites do not break:
#
#         * ``resolution`` — updates the model's input resolution by mutating
#           :attr:`model_config.resolution` in place before the train config is built. This change persists on
#           :attr:`model_config` after :meth:`train` returns. The value must be a positive integer divisible by
#           ``patch_size * num_windows`` for the model variant; a :class:`ValueError` is raised otherwise.
#           :attr:`model_config.positional_encoding_size` is also updated when the config derives it formulaically (``PE
#           == resolution // patch_size``); configs with a pretrained-specific PE value (e.g. ``RFDETRBase`` uses DINOv2's
#           PE=37 at 560 px) are left unchanged to preserve checkpoint compatibility.
#         * ``device`` — normalized via :class:`torch.device` and mapped to PyTorch
#           Lightning trainer arguments. ``"cpu"`` becomes ``accelerator="cpu"``; ``"cuda"`` and ``"cuda:N"`` become
#           ``accelerator="gpu"`` and optionally ``devices=[N]``; ``"mps"`` becomes ``accelerator="mps"``. Other valid
#           torch device types fall back to PTL auto-detection and emit a :class:`UserWarning`.
#         * ``callbacks`` — if the dict contains any non-empty lists a
#           :class:`DeprecationWarning` is emitted; the dict is then discarded. Use PTL
#           :class:`~pytorch_lightning.Callback` objects passed via :func:`~rfdetr.training.build_trainer` instead.
#         * ``start_epoch`` — emits :class:`DeprecationWarning` and is dropped.
#         * ``do_benchmark`` — emits :class:`DeprecationWarning` and is dropped.
#         * ``notes`` — optional user-defined metadata (string, dict, list, or
#           any JSON-serialisable value) stored under the ``"notes"`` key in every ``.pth`` checkpoint produced during
#           training.  The value is also available inside ``args["notes"]`` for full provenance.  Pass the same value to
#           :meth:`export` to embed it in the ONNX file as well.
#
#         After training completes the underlying ``nn.Module`` is synced back onto ``self.model.model`` so that
#         :meth:`predict` and :meth:`export` continue to work without reloading the checkpoint.
#
#         Raises:
#             ImportError: If training dependencies are not installed. Install with
#                 ``pip install "rfdetr[train,loggers]"``.
#             ValueError: If ``resolution`` is not a positive integer or is not
#                 divisible by ``patch_size * num_windows`` for the model variant.
